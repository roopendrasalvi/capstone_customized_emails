# %%
import imaplib
import email
from email.header import decode_header
import webbrowser
import os

# %%
username = ""
password = ""

# %%
imap_server = "imap4.btconnect.com"

# %%
def clean(text):
    # clean text for creating a folder
    return "".join(c if c.isalnum() else "_" for c in text)

# %%
imap = imaplib.IMAP4_SSL(imap_server)
imap.login(username, password)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 imap = imaplib.IMAP4_SSL(imap_server)
#       2 imap.login(username, password)
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\imaplib.py:1315, in IMAP4_SSL.__init__(self, host, port, ssl_context, timeout)
#    1313     ssl_context = ssl._create_stdlib_context()
#    1314 self.ssl_context = ssl_context
# -> 1315 IMAP4.__init__(self, host, port, timeout)
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\imaplib.py:205, in IMAP4.__init__(self, host, port, timeout)
#     201 self._mode_ascii()
#     203 # Open socket to server.
# --> 205 self.open(host, port, timeout)
#     207 try:
#     208     self._connect()
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\imaplib.py:1328, in IMAP4_SSL.open(self, host, port, timeout)
#    1322 def open(self, host='', port=IMAP4_SSL_PORT, timeout=None):
#    1323     """Setup connection to remote server on "host:port".
#    1324         (default: localhost:standard IMAP4 SSL port).
#    1325     This connection will be used by the routines:
#    1326         read, readline, send, shutdown.
#    1327     """
# -> 1328     IMAP4.open(self, host, port, timeout)
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\imaplib.py:315, in IMAP4.open(self, host, port, timeout)
#     313 self.host = host
#     314 self.port = port
# --> 315 self.sock = self._create_socket(timeout)
#     316 self.file = self.sock.makefile('rb')
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\imaplib.py:1318, in IMAP4_SSL._create_socket(self, timeout)
#    1317 def _create_socket(self, timeout):
# -> 1318     sock = IMAP4._create_socket(self, timeout)
#    1319     return self.ssl_context.wrap_socket(sock,
#    1320                                         server_hostname=self.host)
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\imaplib.py:305, in IMAP4._create_socket(self, timeout)
#     303 if timeout is not None:
#     304     return socket.create_connection(address, timeout)
# --> 305 return socket.create_connection(address)
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\socket.py:864, in create_connection(address, timeout, source_address, all_errors)
#     862 try:
#     863     if not all_errors:
# --> 864         raise exceptions[0]
#     865     raise ExceptionGroup("create_connection failed", exceptions)
#     866 finally:
#     867     # Break explicitly a reference cycle
#
# File c:\Users\roopendra.salvi\AppData\Local\anaconda3\Lib\socket.py:849, in create_connection(address, timeout, source_address, all_errors)
#     847 if source_address:
#     848     sock.bind(source_address)
# --> 849 sock.connect(sa)
#     850 # Break explicitly a reference cycle
#     851 exceptions.clear()
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
