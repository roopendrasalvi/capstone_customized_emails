# %%
pip show milvus

# %%
from pymilvus import MilvusClient
from pymilvus import connections

# %%
client = MilvusClient("demo.db")

# %%
# This automatically uses Milvus Lite (no Docker, no server)
connections.connect(
    alias="default",
    uri="milvus.db"     # This is local file storage
)
 
print("Connected to Milvus Lite!")

# %%
pip install -U pymilvus

# %%
client = MilvusClient("milvus_demo.db")

# %%
client = MilvusClient(
  uri= endpoint,
  token= token)

# %%
client.create_collection(
    collection_name="category0",
    dimension=768,  # The vectors we will use in this demo have 768 dimensions
)

# %%
client.create_collection(
    collection_name="category1",
    dimension=768,  # The vectors we will use in this demo have 768 dimensions
)

# %%
client.create_collection(
    collection_name="promotional",
    dimension=768,  # The vectors we will use in this demo have 768 dimensions
)

# %%
client.create_collection(
    collection_name="data",
    dimension=1024,  # The vectors we will use in this demo have 768 dimensions
)

# %%
db_client = MilvusClient(
  uri= endpoint,
  token= token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 db_client = MilvusClient(
#       2   uri= endpoint,
#       3   token= token)
#
# NameError: name 'MilvusClient' is not defined

# %%
client.list_collections()
# Out:
# ['promotional', 'category0', 'category1', 'data']

# %%
from pymilvus import Collection, FieldSchema, CollectionSchema, DataType, connections, utility

# %%
connections.connect(host="localhost", port='19530')
# Out:
# ---------------------------------------------------------------------------
# MilvusException                           Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[40], line 1
# ----> 1 connections.connect(host="localhost", port='19530')
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\connections.py:472, in Connections.connect(self, alias, user, password, db_name, token, _async, **kwargs)
#     470         kwargs["secure"] = True
# --> 472 connect_milvus(**kwargs, user=user, password=password, token=token, db_name=db_name)
#     473 return
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\connections.py:426, in Connections.connect.<locals>.connect_milvus(**kwargs)
#     425 self.remove_connection(alias)
# --> 426 raise e from e
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\connections.py:418, in Connections.connect.<locals>.connect_milvus(**kwargs)
#     417 try:
# ...

# %%
client.using_database("data")

# %%
source_field = FieldSchema(name="source_id", dtype=DataType.INT64, is_primary=True)
vector_field = FieldSchema(name="embedding", dtype=DataType.FLOAT_VECTOR, dim=768)

# %%
schema = CollectionSchema([source_field, vector_field], description="Main collection with partitions")

# %%
CollectionSchema([source_field, vector_field], description="Main collection with partitions")
# Out:
# {'auto_id': False, 'description': 'Main collection with partitions', 'fields': [{'name': 'source_id', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': False}, {'name': 'embedding', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 768}}], 'enable_dynamic_field': False}

# %%
utility.list_collections()
# Out:
# ---------------------------------------------------------------------------
# ConnectionNotExistException               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 utility.list_collections()
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\utility.py:557, in list_collections(timeout, using)
#     534 def list_collections(timeout: Optional[float] = None, using: str = "default") -> list:
#     535     """
#     536     Returns a list of all collection names.
#     537
#    (...)    555         >>> utility.list_collections()
#     556     """
# --> 557     return _get_connection(using).list_collections(timeout=timeout)
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\utility.py:175, in _get_connection(alias)
#     174 def _get_connection(alias: str):
# --> 175     return connections._fetch_handler(alias)
#
# ...

# %%
main_col = Collection(name="promotional", schema=schema)
# Out:
# ---------------------------------------------------------------------------
# ConnectionNotExistException               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 main_col = Collection(name="promotional", schema=schema)
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\collection.py:119, in Collection.__init__(self, name, schema, using, **kwargs)
#     117 self._kwargs = kwargs
#     118 self._num_shards = None
# --> 119 conn = self._get_connection()
#     121 has = conn.has_collection(self._name, **kwargs)
#     122 if has:
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\collection.py:175, in Collection._get_connection(self)
#     174 def _get_connection(self):
# --> 175     return connections._fetch_handler(self._using)
#
# File d:\Capstone_Project\.capstone\Lib\site-packages\pymilvus\orm\connections.py:565, in Connections._fetch_handler(self, alias)
#     563 conn = self._alias_handlers.get(alias, None)
# ...

# %%
fields = [
    FieldSchema(name="id", dtype=DataType.INT64, is_primary=True, auto_id=False),
    FieldSchema(name="vector", dtype=DataType.FLOAT_VECTOR, dim=128)
]
schema = CollectionSchema(fields, description="Main collection with partitions")

# Create main collection
main_col = Collection(name="promotional", schema=schema)

# Create a partition (acts like a sub-collection)
main_col.create_partition("sub_collection_A")


2. Use a Field to Simulate Nested Collections

Add a category or group_id field to your schema.
Filter queries by this field to mimic “sub-collections.”


3. Create Multiple Collections and Manage Them in Code

If you truly need separate storage and indexing, create multiple collections and manage relationships in your application logic.


💡 Tip:
If your goal is multi-tenancy or hierarchical data organization, partitions are the most efficient and cost-effective way in Zilliz Cloud.

If you want, I can give you a full working Python example that creates a main collection, adds multiple “sub-collections” as partitions, and inserts/query data from them. Would you like me to prepare that?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 collections_list[0].create_collection(
#       2     collection_name="sentMails",
#       3     dimension=768,  # The vectors we will use in this demo have 768 dimensions
#       4 )
#
# AttributeError: 'str' object has no attribute 'create_collection'
