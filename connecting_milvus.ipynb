# %%
from pymilvus import MilvusClient

# %%
client = MilvusClient("demo.db")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File d:\Capstone_Project\.env\Lib\site-packages\pymilvus\orm\connections.py:382, in Connections.connect(self, alias, user, password, db_name, token, _async, **kwargs)
#     381 try:
# --> 382     from milvus_lite.server_manager import (
#     383         server_manager_instance,
#     384     )
#     385 except ImportError as e:
#
# ModuleNotFoundError: No module named 'milvus_lite'
#
# The above exception was the direct cause of the following exception:
#
# ConnectionConfigException                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client = MilvusClient("demo.db")
#
# File d:\Capstone_Project\.env\Lib\site-packages\pymilvus\milvus_client\milvus_client.py:67, in MilvusClient.__init__(self, uri, user, password, db_name, token, timeout, **kwargs)
#      44 def __init__(
#      45     self,
# ...
